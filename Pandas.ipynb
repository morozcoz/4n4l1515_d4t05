# %%
# Cargar desde Drive

import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
path = '/content/drive/MyDrive/Colab Notebooks/bases/'

ruta = pd.read_csv(path +'transicion_energetica.csv')

# %%
df = pd.DataFrame(ruta)
df
# Out:
#         ID          País     Año Consumo_Energia_Fosil (GWh)  \
# 0      1.0       Francia  2016.0                     45854.0
# 1      2.0      Alemania  2013.0                     50801.0
# 2      3.0           NaN  2022.0                     41068.0
# 3      4.0     Dinamarca  2020.0                     46651.0
# 4      5.0  Países Bajos  2017.0                     65603.0
# ..     ...           ...     ...                         ...
# 495  496.0        Suecia  2018.0                     65704.0
# 496  497.0      Portugal  2019.0                     39962.0
# 497  498.0     Dinamarca  2023.0                     55102.0
# 498  499.0           NaN  2022.0                     48418.0
# 499  500.0        España  2015.0                     58065.0
#
#     Consumo_Energia_Renovable (GWh) Inversion_Renovable (Millones_USD)  \
# 0                           21918.0                             2119.0
# 1                            8151.0                             2430.0
# ...

# %%
df.head(3) # Encabezado y primeras filas
# Out:
#     ID      País     Año Consumo_Energia_Fosil (GWh)  \
# 0  1.0   Francia  2016.0                     45854.0
# 1  2.0  Alemania  2013.0                     50801.0
# 2  3.0       NaN  2022.0                     41068.0
#
#   Consumo_Energia_Renovable (GWh) Inversion_Renovable (Millones_USD)  \
# 0                         21918.0                             2119.0
# 1                          8151.0                             2430.0
# 2                             NaN                             2530.0
#
#   Emisiones_CO2 (Toneladas) Poblacion (Miles) PIB (Millones_USD)  \
# 0                 1131876.0           41948.0           321439.0
# 1                  922704.0           59578.0           282944.0
# 2                 1067902.0           57792.0           291676.0
#
#   Tasa_Crecimiento_Economico (%)           Fuente_Datos
# 0                           2.61               Encuesta
# 1                           2.65                    NaN
# ...

# %%
df.tail(3) # ultimos filas
# Out:
#         ID       País     Año Consumo_Energia_Fosil (GWh)  \
# 497  498.0  Dinamarca  2023.0                     55102.0
# 498  499.0        NaN  2022.0                     48418.0
# 499  500.0     España  2015.0                     58065.0
#
#     Consumo_Energia_Renovable (GWh) Inversion_Renovable (Millones_USD)  \
# 497                         17329.0                             3253.0
# 498                         11884.0                             3710.0
# 499                         22816.0                                NaN
#
#     Emisiones_CO2 (Toneladas) Poblacion (Miles) PIB (Millones_USD)  \
# 497                 1396677.0           52612.0           351832.0
# 498                 1109846.0           53319.0           395077.0
# 499                 1526844.0           57991.0           312240.0
#
#     Tasa_Crecimiento_Economico (%)   Fuente_Datos
# 497                       3.59 err        Reporte
# 498                            4.4           Otro
# ...

# %%
df.info() # Datos archivo
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 11 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   ID                                  475 non-null    float64
#  1   País                                475 non-null    object
#  2   Año                                 475 non-null    float64
#  3   Consumo_Energia_Fosil (GWh)         477 non-null    object
#  4   Consumo_Energia_Renovable (GWh)     476 non-null    object
#  5   Inversion_Renovable (Millones_USD)  475 non-null    object
#  6   Emisiones_CO2 (Toneladas)           475 non-null    object
#  7   Poblacion (Miles)                   477 non-null    object
#  8   PIB (Millones_USD)                  477 non-null    object
#  9   Tasa_Crecimiento_Economico (%)      475 non-null    object
#  10  Fuente_Datos                        475 non-null    object
# ...

# %%
df.describe() # Estadistica descriptiva de variables númericas
# Out:
#                ID          Año
# count  475.000000   475.000000
# mean   251.823158  2016.421053
# std    144.213063     4.098417
# min      1.000000  2010.000000
# 25%    126.500000  2013.000000
# 50%    253.000000  2016.000000
# 75%    375.500000  2020.000000
# max    500.000000  2023.000000

# %%
df.describe(include = object) # EStadistica variables cualitativas
# Out:
#            País Consumo_Energia_Fosil (GWh) Consumo_Energia_Renovable (GWh)  \
# count       475                         477                             476
# unique       10                         475                             470
# top     Noruega                     52075.0                         23766.0
# freq         64                           2                               2
#
#        Inversion_Renovable (Millones_USD) Emisiones_CO2 (Toneladas)  \
# count                                 475                       475
# unique                                440                       475
# top                                1178.0                 1131876.0
# freq                                    2                         1
#
#        Poblacion (Miles) PIB (Millones_USD) Tasa_Crecimiento_Economico (%)  \
# count                477                477                            475
# unique               473                476                            277
# ...

# %%
df.shape # Dimensiones de dataset (filas, columnas)
# Out:
# (500, 11)

# %%
df.columns # Obtiene las claves
# Out:
# Index(['ID', 'País', 'Año', 'Consumo_Energia_Fosil (GWh)',
#        'Consumo_Energia_Renovable (GWh)', 'Inversion_Renovable (Millones_USD)',
#        'Emisiones_CO2 (Toneladas)', 'Poblacion (Miles)', 'PIB (Millones_USD)',
#        'Tasa_Crecimiento_Economico (%)', 'Fuente_Datos'],
#       dtype='object')

# %%
# Seleccionar multiples columnas
# Consultar varias claves se debe indicar estructura de lista
df[['Consumo_Energia_Renovable (GWh)',
    'Poblacion (Miles)']]
# Out:
#     Consumo_Energia_Renovable (GWh) Poblacion (Miles)
# 0                           21918.0           41948.0
# 1                            8151.0           59578.0
# 2                               NaN           57792.0
# 3                               NaN           47094.0
# 4                           12828.0           64110.0
# ..                              ...               ...
# 495                         25520.0           48509.0
# 496                         21513.0           59315.0
# 497                         17329.0           52612.0
# 498                         11884.0           53319.0
# 499                         22816.0           57991.0
#
# [500 rows x 2 columns]

# %%
lista_claves = list(df.columns)
lista_claves
# Out:
# ['ID',
#  'País',
#  'Año',
#  'Consumo_Energia_Fosil (GWh)',
#  'Consumo_Energia_Renovable (GWh)',
#  'Inversion_Renovable (Millones_USD)',
#  'Emisiones_CO2 (Toneladas)',
#  'Poblacion (Miles)',
#  'PIB (Millones_USD)',
#  'Tasa_Crecimiento_Economico (%)',
#  'Fuente_Datos']

# %%
# Selección por etiquetas
# df.loc[fila, columna]
df.loc[:200, 'Consumo_Energia_Renovable (GWh)']
# Out:
# 0      21918.0
# 1       8151.0
# 2          NaN
# 3          NaN
# 4      12828.0
#         ...
# 196    18887.0
# 197    14265.0
# 198    19427.0
# 199    23166.0
# 200    13863.0
# Name: Consumo_Energia_Renovable (GWh), Length: 201, dtype: object

# %%
# Selección indices
# df.iloc[fila, columna]
df.iloc[10:20,5:7]  # Consulta las filas entre 10 y 20, columnas entre 5 y 7
# Out:
#    Inversion_Renovable (Millones_USD) Emisiones_CO2 (Toneladas)
# 10                             3370.0                 1210022.0
# 11                             4694.0                  827209.0
# 12                                NaN                 1085662.0
# 13                             2013.0                 1179827.0
# 14                             3555.0                 1180493.0
# 15                             4557.0                 1042890.0
# 16                                NaN                 1146860.0
# 17                             4381.0                  870133.0
# 18                         3077.0 err                 1016624.0
# 19                             2455.0                  906579.0

# %%
df.sort_values(by = 'Inversion_Renovable (Millones_USD)') # Ordenar datos
# Out:
#         ID          País     Año Consumo_Energia_Fosil (GWh)  \
# 130  131.0       Noruega  2010.0                     54736.0
# 133  134.0        Suecia  2012.0                     54062.0
# 485  486.0       Noruega  2023.0                     45818.0
# 445  446.0        Suecia  2015.0                     49304.0
# 453  454.0        España  2016.0                     48696.0
# ..     ...           ...     ...                         ...
# 463  464.0  Países Bajos     NaN                     39929.0
# 464  465.0        Italia  2015.0                     43427.0
# 466  467.0   Reino Unido     NaN                     33302.0
# 481  482.0        Suecia  2013.0                     63460.0
# 499  500.0        España  2015.0                     58065.0
#
#     Consumo_Energia_Renovable (GWh) Inversion_Renovable (Millones_USD)  \
# 130                          2595.0                             1157.0
# 133                             NaN                             1178.0
# ...

# %%
df.sort_values(by = 'Inversion_Renovable (Millones_USD)', ascending=False) # Ordenar datos descendente
# Out:
#         ID          País     Año Consumo_Energia_Fosil (GWh)  \
# 74    75.0       Francia  2017.0                     32123.0
# 274  275.0        Italia  2019.0                     46385.0
# 310  311.0       Noruega  2010.0                     43980.0
# 82    83.0        Suecia  2011.0                     50121.0
# 355  356.0        Suecia  2013.0                     50820.0
# ..     ...           ...     ...                         ...
# 463  464.0  Países Bajos     NaN                     39929.0
# 464  465.0        Italia  2015.0                     43427.0
# 466  467.0   Reino Unido     NaN                     33302.0
# 481  482.0        Suecia  2013.0                     63460.0
# 499  500.0        España  2015.0                     58065.0
#
#     Consumo_Energia_Renovable (GWh) Inversion_Renovable (Millones_USD)  \
# 74                      17450.0 err                              979.0
# 274                         19010.0                              781.0
# ...

# %%
df[df['Año'] < 2014]
# Out:
#         ID          País     Año Consumo_Energia_Fosil (GWh)  \
# 1      2.0      Alemania  2013.0                     50801.0
# 9     10.0        Italia  2012.0                     68434.0
# 15    16.0       Noruega  2013.0                     43714.0
# 18    19.0       Noruega  2012.0                     42281.0
# 21    22.0        Italia  2011.0                     46821.0
# ..     ...           ...     ...                         ...
# 482    NaN       Noruega  2010.0                     71552.0
# 487  488.0       Francia  2012.0                     51008.0
# 490  491.0  Países Bajos  2011.0                     70055.0
# 491  492.0     Dinamarca  2011.0                     57175.0
# 494  495.0   Reino Unido  2012.0                     66205.0
#
#     Consumo_Energia_Renovable (GWh) Inversion_Renovable (Millones_USD)  \
# 1                            8151.0                             2430.0
# 9                           15581.0                             3086.0
# ...
